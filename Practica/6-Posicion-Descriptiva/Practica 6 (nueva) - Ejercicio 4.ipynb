# %% [markdown]
# La siguiente tabla contiene valores de población, en cientos de miles, de las 10 ciudades
# más pobladas de 4 paı́ses en el año 1967.
#
#
#     'Argentina''EEUU''Holanda''Japon'

# %%
ciudades <- read.table("./Datos/ciudades.txt", header = TRUE)
# View(ciudades)
boxplot(ciudades)
# Out:
# plot without title
