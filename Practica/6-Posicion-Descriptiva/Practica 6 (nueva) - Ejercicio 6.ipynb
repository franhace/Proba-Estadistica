# %%
# a) Generar muestras de tamaño 25, 50 y 100 de una distribución normal. Construir
# QQ–plots para cada una de ellas. Repetir varias veces.
a<-hist(rnorm(25))
b<-hist(rnorm(50))
c<-hist(rnorm(100))
hist(rnorm(1000))
# Out:
# Plot with title “Histogram of rnorm(25)”
# Plot with title “Histogram of rnorm(50)”
# Plot with title “Histogram of rnorm(100)”
# Plot with title “Histogram of rnorm(1000)”

# %%
data1 <- rnorm(25, mean = 3, sd = 2)
qqnorm(data1)
qqline(data1) 
data2 <- rnorm(50, mean = 3, sd = 2)
qqnorm(data2)
qqline(data2) 
data3 <- rnorm(100, mean = 3, sd = 2)
qqnorm(data3)
qqline(data3) 
data4 <- rnorm(1000, mean = 3, sd = 2)
qqnorm(data4)
qqline(data4)

# %%
# b) Repetir a) para una Γ(5, 1/2 ).
data5 <- rgamma(1000, 5, 1/2)
qqnorm(data5)
qqline(data5)

# %%
# c) Repetir a) para Y = Z/U
# donde Z ∼ N (0, 1) y U ∼ U(0, 1) independientes.
dataZ <- rnorm(50)
qqnorm(dataZ)
qqline(dataZ) 
dataU <- runif(50)
y<-dataZ/dataU
qqnorm(y)
qqline(y)

# %%
data1 <- runif(25)
qqnorm(data1)
qqline(data1) 
data2 <- runif(50)
qqnorm(data2)
qqline(data2) 
data3 <- runif(100)
qqnorm(data3)
qqline(data3) 
data4 <- runif(1000)
qqnorm(data4)
qqline(data4)

# %%
# Out:
# Plot with title “Normal Q-Q Plot”
# Plot with title “Normal Q-Q Plot”
# Plot with title “Normal Q-Q Plot”
# Plot with title “Normal Q-Q Plot”

# %%
# b) Repetir a) para una Γ(5, 1/2 ).
data5 <- rgamma(1000, 5, 1/2)
qqnorm(data5)
qqline(data5)
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
# c) Repetir a) para Y = Z/U
# donde Z ∼ N (0, 1) y U ∼ U(0, 1) independientes.
dataZ <- rnorm(50)
qqnorm(dataZ)
qqline(dataZ) 
dataU <- runif(50)
y<-dataZ/dataU
qqnorm(y)
qqline(y)
# Out:
# Plot with title “Normal Q-Q Plot”
# Plot with title “Normal Q-Q Plot”
# Plot with title “Normal Q-Q Plot”

# %%
data1 <- runif(25)
qqnorm(data1)
qqline(data1) 
data2 <- runif(50)
qqnorm(data2)
qqline(data2) 
data3 <- runif(100)
qqnorm(data3)
qqline(data3) 
data4 <- runif(1000)
qqnorm(data4)
qqline(data4)
# Out:
# Plot with title “Normal Q-Q Plot”
# Plot with title “Normal Q-Q Plot”
# Plot with title “Normal Q-Q Plot”
# Plot with title “Normal Q-Q Plot”
