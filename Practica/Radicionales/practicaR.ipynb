# %%
# lanzamiento moneda equilibrada
frecuencia.relativa<- mean(sample(c(0,1),1000,T))
frecuencia.relativa
# Out:
# [1] 0.493

# %%
a<-dbinom(3,5,0.5)
hist(a)

# %%
a<-dbinom(3,5,0.5)
hist(a)
# Out:
# Plot with title “Histogram of a”
