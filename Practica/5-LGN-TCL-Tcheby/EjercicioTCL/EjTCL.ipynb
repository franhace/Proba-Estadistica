# %% [markdown]
# ![Ejercicio.png](attachment:Ejercicio.png)

# %% [markdown]
# $ 1. \text{Valores exactos de E(X) y V(X):}\\
# E(\widehat{p}_n)=\frac{5}{6} \\
# V(\widehat{p}_n) =\frac{1}{n^2}\sum_{i=1}^{n}{V(X_i)} = \frac{1}{n^2}nV(X_i) = \frac{5/6/6}{1000}$

# %%
# 2) Las estimaríamos usando los datos del archivo pa.txt:
pa <- scan("pa.txt")
media_estimada_a <- mean(pa)
varianza_estimada_a <- mean(pa^2)-mean(pa)^2

# %%
media_estimada_a
# Out:
# [1] 0.8348163

# %%
varianza_estimada_a
# Out:
# [1] 0.0001820662

# %%
#Comparando E(X) exacta y estimada
media_exacta_a <- 5/6
media_exacta_a
media_estimada_a
# Out:
# [1] 0.8333333
# [1] 0.8348163

# %%
#Comparando V(X) exacta y estimada
varianza_exacta_a<-((5/6)*(1/6))/1000
varianza_exacta_a
varianza_estimada_a
# Out:
# [1] 0.0001388889
# [1] 0.0001820662

# %%
# 3) Hacemos un histograma de frecuencias del archivo pa.txt
a<-hist(pa, freq=FALSE)
curve(dnorm(x,mean=mean(pa),sd=sd(pa)), add=TRUE,col="red", lwd=5)
abline(v = media_exacta_a, col = "green", lwd = 3)
abline(v = media_estimada_a, col = "blue", lwd = 3)
# Out:
# Plot with title “Histogram of pa”

# %%
# 4) Hacemos un histograma de frecuencias del archivo pb.txt
pb<- scan("pb.txt")
media_exacta_b<-5/12
media_estimada_b <- mean(pb)
varianza_estimada_b <- mean(pb^2)-mean(pb)^2
varianza_exacta_b<- ((1/6)*(5/12))/1000
hist(pb, freq=FALSE)
curve(dnorm(x,mean=mean(pb),sd=sd(pb)), add=TRUE,col="red", lwd=5)
abline(v = media_exacta_b, col = "green", lwd = 3)
abline(v = media_estimada_b, col = "blue", lwd = 3)
# Out:
# Plot with title “Histogram of pb”

# %%
#Comparando E(X) exacta y estimada
media_exacta_b
media_estimada_b
varianza_exacta_b
varianza_estimada_b
# Out:
# [1] 0.4166667
# [1] 0.419559
# [1] 6.951396e-05
# [1] 0.0001852554

# %%
# Hacemos un histograma de frecuencias del archivo pc.txt
pc<- scan("pc.txt")
media_exacta_c<-1/6
media_estimada_c <- mean(pc)
varianza_estimada_c <- mean(pc^2)-mean(pc)^2
varianza_exacta_c<-1/6*1/6/1000
hist(pc, freq=FALSE)
curve(dnorm(x,mean=mean(pc),sd=sd(pc)), add=TRUE,col="red", lwd=5)
abline(v = media_exacta_c, col = "green", lwd = 3)
abline(v = media_estimada_c, col = "blue", lwd = 3)
media_exacta_c
media_estimada_c
varianza_estimada_c
varianza_exacta_c
# Out:
# [1] 0.1666667
# [1] 0.165342
# [1] 0.0001106541
# [1] 2.777778e-05
# Plot with title “Histogram of pc”

# %%
# 5)
a=(pa)
b=(pb)
c=(pc)
#hist(a, xlim=c(0,10), col=rgb(1,1,0,1/4))
# hist(b, col=rgb(1,0,0,0.5), add=T )
# hist(c, col=rgb(1,0,1,0.5), add=T )
hist(a, col=rgb(1,0,0,0.5),xlim=c(0.1,0.9), ylim=c(0,30), )
hist(b, col=rgb(1,1,1,0.5), add=T )
hist(c, col=rgb(0,0,1,0.5), add=T)
box()
