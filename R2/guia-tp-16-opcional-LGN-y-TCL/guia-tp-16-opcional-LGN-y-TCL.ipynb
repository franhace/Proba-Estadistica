# %% [markdown]
# # Práctica LGN y TCL: Opcional

# %% [markdown]
# ## 1.
#
# $$(b-a) \frac{\sum_{i=1}^{n} \frac{1}{\sqrt{2\pi}} e^{-\frac{u_i^2}{2}}}{n} $$

# %%
numeric_approx_1 <- function(n, a,b){
    unifs <- runif(n, min=a, max=b)
    return ((b-a)/n * sum(1/sqrt(2*pi) * exp(-0.5*unifs^2)))
}

# %% [markdown]
# ### i.

# %%
a <- -1.96
b <-  1.96
numeric_approx_1(a,b,n=100)
numeric_approx_1(a,b,n=1000)
numeric_approx_1(a,b,n=50000)
# Out:
# [1] 0.864218
# [1] 0.9559561
# [1] 0.9463214

# %%
pnorm(q=b)-pnorm(q=a)
# Out:
# [1] 0.9500042

# %%
gridx <- 1:5000
plot(gridx,lapply(gridx, numeric_approx_1, a, b), pch=20, col='steelblue')
abline(h=pnorm(q=b)-pnorm(q=a), col='red')
# Out:
# plot without title

# %% [markdown]
# ### ii.

# %%
a <- -2
b <-  1

# %%
numeric_approx_1(a,b,n=100)
numeric_approx_1(a,b,n=1000)
numeric_approx_1(a,b,n=50000)
# Out:
# [1] 0.8076135
# [1] 0.8122443
# [1] 0.8177666

# %%
pnorm(q=b)-pnorm(q=a)
# Out:
# [1] 0.8185946

# %% [markdown]
# ### iii.

# %%
gridx <- 1:5000
plot(gridx,lapply(gridx, numeric_approx_1, a, b), pch=20, col='steelblue')
abline(h=pnorm(q=b)-pnorm(q=a), col='red')
# Out:
# plot without title

# %%
a <- 0
b <- 2.34

# %%
numeric_approx_1(a,b,n=100)
numeric_approx_1(a,b,n=1000)
numeric_approx_1(a,b,n=50000)
# Out:
# [1] 0.4869523
# [1] 0.4877357
# [1] 0.4891673

# %%
pnorm(q=b)-pnorm(q=a)
# Out:
# [1] 0.4903581

# %%
gridx <- 1:5000
plot(gridx,lapply(gridx, numeric_approx_1, a, b), pch=20, col='steelblue')
abline(h=pnorm(q=b)-pnorm(q=a), col='red')
# Out:
# plot without title

# %% [markdown]
# ### b)
# $Z_1, Z_2, \dots, Z_n \ \ i.i.d.$
#
# $Z_i \sim \mathcal N(0,1) $
#
# $$\frac 1 n \sum_{i=1}^{n} \mathbb 1_{(a,b)} (Z_i)$$
#
# > Es razonable ya que se cuenta la proporción de valores que caen en el intervalo (a,b), donde estos valores son generador a partir de una distribución Normal(0,1), o sea, se distribuyen siguiendo esa función de probabilidad, y por ende, en el límite, las proporciones se corresponderán con la probabilidad real.
# >
# > Otra forma de verlo es pensando en un histograma, donde al final sumamos los bins dentro de ese intervalo.

# %%
numeric_approx_2 <- function(n, a, b){
    norms <- rnorm(n)
    return (1/n * sum(norms>a & norms<b))
}

# %%
a <- -1.96
b <-  1.96
numeric_approx_2(a,b,n=100)
numeric_approx_2(a,b,n=1000)
numeric_approx_2(a,b,n=50000)
# Out:
# [1] 0.93
# [1] 0.942
# [1] 0.94976

# %%
pnorm(q=b)-pnorm(q=a)
# Out:
# [1] 0.9500042

# %%
gridx <- 1:5000
plot(gridx,lapply(gridx, numeric_approx_2, a, b), pch=20, col='orange')
abline(h=pnorm(q=b)-pnorm(q=a), col='red')
# Out:
# plot without title

# %% [markdown]
# ### ii.

# %%
a <- -2
b <-  1

# %%
numeric_approx_2(a,b,n=100)
numeric_approx_2(a,b,n=1000)
numeric_approx_2(a,b,n=50000)
# Out:
# [1] 0.82
# [1] 0.825
# [1] 0.82168

# %%
pnorm(q=b)-pnorm(q=a)
# Out:
# [1] 0.8185946

# %% [markdown]
# ### iii.

# %%
gridx <- 1:5000
plot(gridx,lapply(gridx, numeric_approx_2, a, b), pch=20, col='orange')
abline(h=pnorm(q=b)-pnorm(q=a), col='red')
# Out:
# plot without title

# %%
a <- 0
b <- 2.34

# %%
numeric_approx_2(a,b,n=100)
numeric_approx_2(a,b,n=1000)
numeric_approx_2(a,b,n=50000)
# Out:
# [1] 0.53
# [1] 0.502
# [1] 0.48706

# %%
pnorm(q=b)-pnorm(q=a)
# Out:
# [1] 0.4903581

# %%
gridx <- 1:5000
plot(gridx,lapply(gridx, numeric_approx_2, a, b), pch=20, col='orange')
abline(h=pnorm(q=b)-pnorm(q=a), col='red')
# Out:
# plot without title

# %% [markdown]
# Empiric comparisson between methods:

# %%
a <- -1.96
b <-  1.96
gridx <- 1:5000
plot(gridx,lapply(gridx, numeric_approx_1, a, b), pch=20, col='steelblue')
points(gridx,lapply(gridx, numeric_approx_2, a, b), pch=20, col=rgb(1,0.7,0,0.5))
abline(h=pnorm(q=b)-pnorm(q=a), col='red')
# Out:
# plot without title

# %%
a <- -2
b <-  1
gridx <- 1:5000
plot(gridx,lapply(gridx, numeric_approx_1, a, b), pch=20, col='steelblue')
points(gridx,lapply(gridx, numeric_approx_2, a, b), pch=20, col=rgb(1,0.7,0,0.5))
abline(h=pnorm(q=b)-pnorm(q=a), col='red')
# Out:
# plot without title

# %%
a <- 0
b <- 2.34
gridx <- 1:5000
plot(gridx,lapply(gridx, numeric_approx_1, a, b), pch=20, cex=0.5, col='steelblue')
points(gridx,lapply(gridx, numeric_approx_2, a, b), pch=20, cex=0.5, col=rgb(1,0.7,0,0.5))
abline(h=pnorm(q=b)-pnorm(q=a), col='red')
# Out:
# plot without title

# %% [markdown]
# ## 2.

# %% [markdown]
# ## 3.

# %%
gridx <- seq(-2,10,0.01)
datos <- dlnorm(gridx)
plot(gridx, datos)
# Out:
# plot without title

# %%
n <- 1000
datos <- rlnorm(n)

# %%
plot(density(datos), main="Lognormal distribution")
# Out:
# Plot with title “Lognormal distribution”
